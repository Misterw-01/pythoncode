# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/Sober_Images8.png')
img.shape
# Out:
# (279, 279, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (279, 279)

# %%
gray
# Out:
# array([[ 58,  50,  60, ..., 118, 118, 118],
#        [ 54,  46,  60, ..., 116, 116, 116],
#        [ 51,  46,  58, ..., 116, 116, 116],
#        ...,
#        [ 12,  18,  20, ..., 112, 119, 104],
#        [ 10,  20,  26, ..., 115, 128, 106],
#        [ 11,  21,  25, ..., 116, 128, 106]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 22,  31, 235, 235]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (22, 31, 235, 235)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/Sober_Images8.png')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Sober_Images8.png')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/Sober_Images8.png')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/Sober_Images8.png')
cropped_image_no_2_eyes
# Out:
# array([[[54, 54, 60],
#         [38, 38, 44],
#         [32, 32, 38],
#         ...,
#         [40, 43, 47],
#         [38, 41, 45],
#         [37, 40, 44]],
#
#        [[44, 44, 50],
#         [34, 34, 40],
#         [35, 35, 41],
#         ...,
#         [41, 44, 48],
#         [40, 43, 47],
#         [38, 41, 45]],
#
#        [[32, 32, 38],
#         [33, 33, 39],
#         [42, 42, 48],
#         ...,
#         [41, 44, 48],
#         [40, 43, 47],
#         [38, 41, 45]],
#
#        ...,
#
#        [[11, 12, 16],
#         [16, 19, 23],
#         [ 7,  9, 17],
#         ...,
#         [ 0,  6, 13],
#         [20, 26, 33],
#         [72, 78, 83]],
#
#        [[12, 13, 17],
#         [16, 19, 24],
#         [ 6,  9, 17],
#         ...,
#         [ 0,  5, 12],
#         [21, 27, 34],
#         [77, 83, 88]],
#
#        [[13, 13, 19],
#         [16, 19, 24],
#         [ 7, 10, 18],
#         ...,
#         [ 4, 10, 17],
#         [24, 30, 37],
#         [73, 79, 84]]], dtype=uint8)

# %%
path_to_data = "./Sober_Drunk_Dataset/"
path_to_cr_data = "./Sober_Drunk_Dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./Sober_Drunk_Dataset/Severely_Drunk',
#  './Sober_Drunk_Dataset/Slightly_Drunk',
#  './Sober_Drunk_Dataset/Sober_Images']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
drunk_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    drunk_name = img_dir.split('/')[-1]
    print(drunk_name)

    drunk_file_names_dict[drunk_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + drunk_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = drunk_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            drunk_file_names_dict[drunk_name].append(cropped_file_path)
            count += 1
# Out:
# Severely_Drunk
# Generating cropped images in folder:  ./Sober_Drunk_Dataset/cropped/Severely_Drunk
# Slightly_Drunk
# Generating cropped images in folder:  ./Sober_Drunk_Dataset/cropped/Slightly_Drunk
# Sober_Images
# Generating cropped images in folder:  ./Sober_Drunk_Dataset/cropped/Sober_Images

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (201, 201, 3)

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
drunk_file_names_dict
# Out:
# {'Severely_Drunk': ['./Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk1.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk2.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk3.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk4.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk5.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk6.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk7.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk8.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk9.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk10.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk11.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk12.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk/Severely_Drunk13.png',
# ...

# %%
class_dict = {}
count = 0
for drunk_name in drunk_file_names_dict.keys():
    class_dict[drunk_name] = count
    count = count + 1
class_dict
# Out:
# {'Severely_Drunk': 0, 'Slightly_Drunk': 1, 'Sober_Images': 2}

# %%
X, y = [], []
for drunk_name, training_files in drunk_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[drunk_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[180],
#        [167],
#        [175],
#        ...,
#        [101],
#        [212],
#        [  4]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (4192, 4096)

# %%
X[0]
# Out:
# array([180., 167., 175., ..., 101., 212.,   4.])

# %%
drunk_file_names_dict = {}
for img_dir in cropped_image_dirs:
    drunk_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    drunk_file_names_dict[drunk_name] = file_list
drunk_file_names_dict
# Out:
# {'Severely_Drunk': ['./Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk1.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk10.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk100.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk101.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk102.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk103.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk104.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk105.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk106.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk107.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk108.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk109.png',
#   './Sober_Drunk_Dataset/cropped/Severely_Drunk\\Severely_Drunk11.png',
# ...

# %%
#Data cleaning process is done. Now we are ready to train our model
#We will use SVM with rbf kernel tuned with heuristic finetuning

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.9522900763358778

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       200
#            1       0.92      0.96      0.94       380
#            2       0.99      0.97      0.98       468
#
#     accuracy                           0.95      1048
#    macro avg       0.95      0.94      0.94      1048
# weighted avg       0.95      0.95      0.95      1048

# %%
#Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.940521
# 1        random_forest    0.884864
# 2  logistic_regression    0.889947
#
#                                     best_params
# 0          {'svc__C': 10, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=10, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9522900763358778

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.9083969465648855

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8998091603053435

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[181,  19,   0],
#        [ 11, 364,   5],
#        [  3,  12, 453]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Severely_Drunk': 0, 'Slightly_Drunk': 1, 'Sober_Images': 2}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ...
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
